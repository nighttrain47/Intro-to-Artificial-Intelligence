# %% [markdown]
# # Bài Lab: Thuật Toán Di Truyền (Genetic Algorithm)
#
# ## Mục tiêu
# - Hiểu rõ nguyên lý hoạt động của thuật toán di truyền.
# - Áp dụng thuật toán để giải các bài toán tối ưu hóa.
# - Phân tích và trực quan hóa kết quả.
# - Thực hành với các bài tập mở rộng để nâng cao kỹ năng.
#
# ## Lý thuyết
# Thuật toán di truyền (Genetic Algorithm - GA) là một phương pháp tìm kiếm dựa trên cơ chế tiến hóa tự nhiên, lấy cảm hứng từ thuyết tiến hóa của Darwin. GA được sử dụng để tìm lời giải gần tối ưu cho các bài toán tối ưu hóa phức tạp.
#
# ### Các bước chính của thuật toán:
# 1. **Khởi tạo quần thể**: Tạo ngẫu nhiên một tập hợp các cá thể (giải pháp tiềm năng).
# 2. **Đánh giá độ thích nghi (Fitness Evaluation)**: Tính giá trị hàm mục tiêu cho mỗi cá thể.
# 3. **Lựa chọn (Selection)**: Chọn các cá thể tốt nhất để lai ghép (thường sử dụng các phương pháp như Tournament Selection hoặc Roulette Wheel).
# 4. **Lai ghép (Crossover)**: Kết hợp hai cá thể để tạo ra cá thể mới.
# 5. **Đột biến (Mutation)**: Thay đổi ngẫu nhiên một số gen để duy trì tính đa dạng.
# 6. **Lặp lại**: Quay lại bước 2 cho đến khi đạt điều kiện dừng (số thế hệ hoặc giá trị fitness mong muốn).
#
# ![image.png](attachment:image.png)
#
# ### Ứng dụng
# - Tối ưu hóa hàm số.
# - Bài toán lập lịch.
# - Thiết kế kỹ thuật, machine learning, v.v.
#
# ## Các ví dụ minh họa
# Chúng ta sẽ thực hiện hai ví dụ:
#
# 1. Tìm giá trị tối đa của hàm số $f(x) = -x^2 + 10x + 50$ trong khoảng $x \in [0, 10]$.
# 2. Tìm giá trị tối thiểu của hàm số $g(x, y) = x^2 + y^2$ trong khoảng $x, y \in [-5, 5]$.
#
# Ngoài ra, chúng ta sẽ trực quan hóa sự thay đổi của giá trị fitness qua các thế hệ.

# %% [markdown]
# ## Ví dụ 1: Tối ưu hóa hàm một biến
#
# ### Bài toán
# Tìm $x$ sao cho
# $$
# f(x) = -(x^2) + 10x + 50
# $$
# đạt giá trị lớn nhất trong khoảng
# $$
# x \in [0, 10].
# $$

# %% [markdown]
# # Mã giả
# ```plaintext
# Tạo quần thể mới rỗng
# Lặp cho đến khi quần thể mới đủ N cá thể:
#     Chọn cha mẹ 1 bằng Tournament Selection:
#         - Chọn ngẫu nhiên tournament_size cá thể trong quần thể
#         - Chọn cá thể có fitness cao nhất làm cha mẹ 1
#     Chọn cha mẹ 2 bằng Tournament Selection tương tự
#
#     Thực hiện lai ghép (crossover) giữa cha mẹ 1 và cha mẹ 2 với xác suất crossover_rate:
#         Nếu crossover thành công:
#             Tạo con mới có giá trị trung bình của cha mẹ
#         Ngược lại:
#             Con mới là cha mẹ 1
#
#     Thực hiện đột biến cho con mới với xác suất mutation_rate:
#         Nếu đột biến:
#             Gán con mới giá trị ngẫu nhiên trong [min_val, max_val]
#
#     Thêm con mới vào quần thể mới
#
# Cập nhật quần thể hiện tại = quần thể mới
# In ra cá thể tốt nhất và giá trị fitness tương ứng của thế hệ

# %%
import numpy as np
import random
import matplotlib.pyplot as plt

# Hàm mục tiêu
def fitness_function(x):
    return -(x**2) + 10*x + 50

# Khởi tạo quần thể
def initialize_population(pop_size, min_val, max_val):
    return [random.uniform(min_val, max_val) for _ in range(pop_size)]

# Lựa chọn (Tournament Selection)
def select_parents(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return (parent1 + parent2) / 2
    return parent1

# Đột biến
def mutate(individual, mutation_rate=0.1, min_val=0, max_val=10):
    if random.random() < mutation_rate:
        return random.uniform(min_val, max_val)
    return individual

# Thuật toán di truyền
def genetic_algorithm_example1(pop_size=50, generations=100, min_val=0, max_val=10):
    population = initialize_population(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function(x) for x in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(best_fitness)
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents(population, fitness_values)
            parent2 = select_parents(population, fitness_values)
            child = crossover(parent1, parent2)
            child = mutate(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function(x) for x in population])]
        print(f'Thế hệ {generation + 1}: x = {best_individual:.4f}, f(x) = {best_fitness:.4f}')
    
    best_fitness = max([fitness_function(x) for x in population])
    best_individual = population[np.argmax([fitness_function(x) for x in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị f(x) tốt nhất')
    plt.title('Sự thay đổi của f(x) qua các thế hệ')
    plt.show()
    
    return best_individual, best_fitness

# Chạy thuật toán
best_x, best_f = genetic_algorithm_example1()
print(f'\nKết quả cuối cùng: x = {best_x:.4f}, f(x) = {best_f:.4f}')
# Out:
# Thế hệ 1: x = 4.9903, f(x) = 74.9992
# Thế hệ 2: x = 5.0034, f(x) = 74.9999
# Thế hệ 3: x = 5.0034, f(x) = 75.0000
# Thế hệ 4: x = 5.0010, f(x) = 75.0000
# Thế hệ 5: x = 5.0000, f(x) = 75.0000
# Thế hệ 6: x = 5.0000, f(x) = 75.0000
# Thế hệ 7: x = 5.0000, f(x) = 75.0000
# Thế hệ 8: x = 5.0000, f(x) = 75.0000
# Thế hệ 9: x = 5.0000, f(x) = 75.0000
# Thế hệ 10: x = 5.0000, f(x) = 75.0000
# Thế hệ 11: x = 5.0000, f(x) = 75.0000
# Thế hệ 12: x = 5.0000, f(x) = 75.0000
# Thế hệ 13: x = 5.0000, f(x) = 75.0000
# Thế hệ 14: x = 5.0000, f(x) = 75.0000
# Thế hệ 15: x = 5.0000, f(x) = 75.0000
# Thế hệ 16: x = 5.0000, f(x) = 75.0000
# Thế hệ 17: x = 5.0000, f(x) = 75.0000
# Thế hệ 18: x = 5.0000, f(x) = 75.0000
# Thế hệ 19: x = 5.0000, f(x) = 75.0000
# Thế hệ 20: x = 5.0000, f(x) = 75.0000
# Thế hệ 21: x = 5.0000, f(x) = 75.0000
# Thế hệ 22: x = 5.0000, f(x) = 75.0000
# Thế hệ 23: x = 5.0000, f(x) = 75.0000
# Thế hệ 24: x = 5.0000, f(x) = 75.0000
# Thế hệ 25: x = 5.0000, f(x) = 75.0000
# Thế hệ 26: x = 5.0000, f(x) = 75.0000
# Thế hệ 27: x = 5.0000, f(x) = 75.0000
# Thế hệ 28: x = 5.0000, f(x) = 75.0000
# Thế hệ 29: x = 5.0000, f(x) = 75.0000
# Thế hệ 30: x = 5.0000, f(x) = 75.0000
# Thế hệ 31: x = 5.0000, f(x) = 75.0000
# Thế hệ 32: x = 5.0000, f(x) = 75.0000
# Thế hệ 33: x = 5.0000, f(x) = 75.0000
# Thế hệ 34: x = 5.0000, f(x) = 75.0000
# Thế hệ 35: x = 5.0000, f(x) = 75.0000
# Thế hệ 36: x = 5.0000, f(x) = 75.0000
# Thế hệ 37: x = 5.0000, f(x) = 75.0000
# Thế hệ 38: x = 5.0000, f(x) = 75.0000
# Thế hệ 39: x = 5.0000, f(x) = 75.0000
# Thế hệ 40: x = 5.0000, f(x) = 75.0000
# Thế hệ 41: x = 5.0000, f(x) = 75.0000
# Thế hệ 42: x = 5.0000, f(x) = 75.0000
# Thế hệ 43: x = 5.0000, f(x) = 75.0000
# Thế hệ 44: x = 5.0000, f(x) = 75.0000
# Thế hệ 45: x = 5.0000, f(x) = 75.0000
# Thế hệ 46: x = 5.0000, f(x) = 75.0000
# Thế hệ 47: x = 5.0000, f(x) = 75.0000
# Thế hệ 48: x = 5.0000, f(x) = 75.0000
# Thế hệ 49: x = 5.0000, f(x) = 75.0000
# Thế hệ 50: x = 5.0000, f(x) = 75.0000
# Thế hệ 51: x = 5.0000, f(x) = 75.0000
# Thế hệ 52: x = 5.0000, f(x) = 75.0000
# Thế hệ 53: x = 5.0000, f(x) = 75.0000
# Thế hệ 54: x = 5.0000, f(x) = 75.0000
# Thế hệ 55: x = 5.0000, f(x) = 75.0000
# Thế hệ 56: x = 5.0000, f(x) = 75.0000
# Thế hệ 57: x = 5.0000, f(x) = 75.0000
# Thế hệ 58: x = 5.0000, f(x) = 75.0000
# Thế hệ 59: x = 5.0000, f(x) = 75.0000
# Thế hệ 60: x = 5.0000, f(x) = 75.0000
# Thế hệ 61: x = 5.0000, f(x) = 75.0000
# Thế hệ 62: x = 5.0000, f(x) = 75.0000
# Thế hệ 63: x = 5.0000, f(x) = 75.0000
# Thế hệ 64: x = 5.0000, f(x) = 75.0000
# Thế hệ 65: x = 5.0000, f(x) = 75.0000
# Thế hệ 66: x = 5.0000, f(x) = 75.0000
# Thế hệ 67: x = 5.0000, f(x) = 75.0000
# Thế hệ 68: x = 5.0000, f(x) = 75.0000
# Thế hệ 69: x = 5.0000, f(x) = 75.0000
# Thế hệ 70: x = 5.0000, f(x) = 75.0000
# Thế hệ 71: x = 5.0000, f(x) = 75.0000
# Thế hệ 72: x = 5.0000, f(x) = 75.0000
# Thế hệ 73: x = 5.0000, f(x) = 75.0000
# Thế hệ 74: x = 5.0000, f(x) = 75.0000
# Thế hệ 75: x = 5.0000, f(x) = 75.0000
# Thế hệ 76: x = 5.0000, f(x) = 75.0000
# Thế hệ 77: x = 5.0000, f(x) = 75.0000
# Thế hệ 78: x = 5.0000, f(x) = 75.0000
# Thế hệ 79: x = 5.0000, f(x) = 75.0000
# Thế hệ 80: x = 5.0000, f(x) = 75.0000
# Thế hệ 81: x = 5.0000, f(x) = 75.0000
# Thế hệ 82: x = 5.0000, f(x) = 75.0000
# Thế hệ 83: x = 5.0000, f(x) = 75.0000
# Thế hệ 84: x = 5.0000, f(x) = 75.0000
# Thế hệ 85: x = 5.0000, f(x) = 75.0000
# Thế hệ 86: x = 5.0000, f(x) = 75.0000
# Thế hệ 87: x = 5.0000, f(x) = 75.0000
# Thế hệ 88: x = 5.0000, f(x) = 75.0000
# Thế hệ 89: x = 5.0000, f(x) = 75.0000
# Thế hệ 90: x = 5.0000, f(x) = 75.0000
# Thế hệ 91: x = 5.0000, f(x) = 75.0000
# Thế hệ 92: x = 5.0000, f(x) = 75.0000
# Thế hệ 93: x = 5.0000, f(x) = 75.0000
# Thế hệ 94: x = 5.0000, f(x) = 75.0000
# Thế hệ 95: x = 5.0000, f(x) = 75.0000
# Thế hệ 96: x = 5.0000, f(x) = 75.0000
# Thế hệ 97: x = 5.0000, f(x) = 75.0000
# Thế hệ 98: x = 5.0000, f(x) = 75.0000
# Thế hệ 99: x = 5.0000, f(x) = 75.0000
# Thế hệ 100: x = 5.0000, f(x) = 75.0000
# Kết quả cuối cùng: x = 5.0000, f(x) = 75.0000

# %% [markdown]
# ## Ví dụ 2: Tối ưu hóa hàm hai biến
#
# ### Bài toán
# Tìm $(x, y)$ sao cho
# $$
# g(x, y) = x^2 + y^2
# $$
# đạt giá trị nhỏ nhất trong khoảng
# $$
# x, y \in [-5, 5].
# $$

# %% [markdown]
# ### Mã giả
#
# ```plaintext
# Tạo quần thể mới rỗng
# Lặp cho đến khi quần thể mới đủ N cá thể:
#     Chọn cha mẹ 1 bằng Tournament Selection trên quần thể hiện tại
#     Chọn cha mẹ 2 bằng Tournament Selection trên quần thể hiện tại
#     Thực hiện lai ghép (crossover) giữa cha mẹ 1 và cha mẹ 2 với xác suất crossover_rate:
#         Nếu crossover thành công:
#             Tạo con mới bằng trung bình giá trị (x, y) của cha mẹ
#         Ngược lại:
#             Con mới là cha mẹ 1
#     Thực hiện đột biến cho con mới với xác suất mutation_rate từng biến:
#         Nếu đột biến:
#             Gán giá trị ngẫu nhiên trong [min_val, max_val] cho biến tương ứng
#     Thêm con mới vào quần thể mới
#
# Cập nhật quần thể hiện tại = quần thể mới
# In kết quả tốt nhất thế hệ

# %%
# Hàm mục tiêu
def fitness_function_2d(x, y):
    return -(x**2 + y**2)  # Sử dụng dấu âm vì GA tìm max

# Khởi tạo quần thể
def initialize_population_2d(pop_size, min_val, max_val):
    return [(random.uniform(min_val, max_val), random.uniform(min_val, max_val)) for _ in range(pop_size)]

# Lựa chọn
def select_parents_2d(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover_2d(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return ((parent1[0] + parent2[0]) / 2, (parent1[1] + parent2[1]) / 2)
    return parent1

# Đột biến
def mutate_2d(individual, mutation_rate=0.1, min_val=-5, max_val=5):
    x, y = individual
    if random.random() < mutation_rate:
        x = random.uniform(min_val, max_val)
    if random.random() < mutation_rate:
        y = random.uniform(min_val, max_val)
    return (x, y)

# Thuật toán di truyền
def genetic_algorithm_example2(pop_size=50, generations=100, min_val=-5, max_val=5):
    population = initialize_population_2d(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function_2d(x, y) for x, y in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(-best_fitness)  # Chuyển về giá trị thực
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents_2d(population, fitness_values)
            parent2 = select_parents_2d(population, fitness_values)
            child = crossover_2d(parent1, parent2)
            child = mutate_2d(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
        print(f'Thế hệ {generation + 1}: (x, y) = ({best_individual[0]:.4f}, {best_individual[1]:.4f}), g(x, y) = {-best_fitness:.4f}')
    
    best_fitness = max([fitness_function_2d(x, y) for x, y in population])
    best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị g(x, y) tốt nhất')
    plt.title('Sự thay đổi của g(x, y) qua các thế hệ')
    plt.show()
    
    return best_individual, -best_fitness

# Chạy thuật toán
best_xy, best_g = genetic_algorithm_example2()
print(f'\nKết quả cuối cùng: (x, y) = ({best_xy[0]:.4f}, {best_xy[1]:.4f}), g(x, y) = {best_g:.4f}')
# Out:
# Thế hệ 1: (x, y) = (-0.3979, -0.3380), g(x, y) = 0.3585
# Thế hệ 2: (x, y) = (0.0536, 0.0918), g(x, y) = 0.2726
# Thế hệ 3: (x, y) = (0.0189, -0.0309), g(x, y) = 0.0113
# Thế hệ 4: (x, y) = (0.0378, -0.0500), g(x, y) = 0.0013
# Thế hệ 5: (x, y) = (0.0034, 0.0117), g(x, y) = 0.0039
# Thế hệ 6: (x, y) = (-0.0131, 0.0024), g(x, y) = 0.0001
# Thế hệ 7: (x, y) = (-0.0026, -0.0056), g(x, y) = 0.0002
# Thế hệ 8: (x, y) = (0.0008, -0.0019), g(x, y) = 0.0000
# Thế hệ 9: (x, y) = (-0.0009, 0.0013), g(x, y) = 0.0000
# Thế hệ 10: (x, y) = (-0.0009, 0.0013), g(x, y) = 0.0000
# Thế hệ 11: (x, y) = (0.0005, -0.0014), g(x, y) = 0.0000
# Thế hệ 12: (x, y) = (-0.0005, -0.0009), g(x, y) = 0.0000
# Thế hệ 13: (x, y) = (-0.0000, -0.0010), g(x, y) = 0.0000
# Thế hệ 14: (x, y) = (-0.0000, -0.0010), g(x, y) = 0.0000
# Thế hệ 15: (x, y) = (-0.0000, -0.0010), g(x, y) = 0.0000
# Thế hệ 16: (x, y) = (-0.0000, -0.0010), g(x, y) = 0.0000
# Thế hệ 17: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 18: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 19: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 20: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 21: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 22: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 23: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 24: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 25: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 26: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 27: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 28: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 29: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 30: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 31: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 32: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 33: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 34: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 35: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 36: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 37: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 38: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 39: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 40: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 41: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 42: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 43: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 44: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 45: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 46: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 47: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 48: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 49: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 50: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 51: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 52: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 53: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 54: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 55: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 56: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 57: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 58: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 59: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 60: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 61: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 62: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 63: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 64: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 65: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 66: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 67: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 68: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 69: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 70: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 71: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 72: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 73: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 74: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 75: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 76: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 77: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 78: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 79: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 80: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 81: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 82: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 83: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 84: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 85: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 86: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 87: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 88: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 89: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 90: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 91: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 92: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 93: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 94: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 95: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 96: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 97: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 98: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 99: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Thế hệ 100: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000
# Kết quả cuối cùng: (x, y) = (0.0002, -0.0010), g(x, y) = 0.0000

# %% [markdown]
# ## Phân tích kết quả
# - **Ví dụ 1**: Hàm \\( f(x) \\) là một hàm bậc hai, có giá trị tối đa tại \\( x = 5 \\). Thuật toán di truyền sẽ hội tụ về giá trị này sau một số thế hệ.
# - **Ví dụ 2**: Hàm \\( g(x, y) \\) có giá trị tối thiểu tại \\( (0, 0) \\). Thuật toán sẽ tìm cách giảm giá trị \\( x^2 + y^2 \\) về gần 0.

# %% [markdown]
# # Bài tập 1
# # Thay đổi hàm mục tiêu**: Thử áp dụng thuật toán cho hàm $h(x) = sin(x) + cos(x)$ trong khoảng $x \in [0, 2\pi]$. So sánh kết quả với nghiệm chính xác.
#
# ## Tối ưu hàm $h(x) = \sin(x) + \cos(x)$ bằng Thuật Toán Di Truyền (Genetic Algorithm)
#
# ## Mục tiêu
# - Tối ưu hàm:
#   $$
#   h(x) = \sin(x) + \cos(x)
#   $$
#   trong miền:
#   $$
#   x \in [0, 2\pi]
#   $$
# - Tìm giá trị **x** sao cho **h(x)** đạt giá trị lớn nhất.
#
# ---
#
# ## Phân tích nghiệm chính xác
#
# Ta có:
# $$
# h(x) = \sin(x) + \cos(x) = \sqrt{2} \cdot \sin\left(x + \frac{\pi}{4}\right)
# \Rightarrow \max h(x) = \sqrt{2} \approx 1.4142
# $$
#
# Xảy ra khi:
# $$
# x = \frac{\pi}{4} \approx 0.7854
# $$
#
# ---
#
# ## Ý tưởng thuật toán di truyền (GA)
#
# 1. **Mã hóa**: Biểu diễn giá trị \( x \) bằng chuỗi nhị phân dài 16 bit.
# 2. **Giải mã**: Chuyển từ chuỗi nhị phân sang giá trị thực trong khoảng \([0, 2\pi]\).
# 3. **Fitness**: Sử dụng chính giá trị \( h(x) \) làm độ thích nghi.
# 4. **Chọn lọc**: Roulette Wheel Selection.
# 5. **Lai ghép**: Lai 1 điểm với xác suất cao.
# 6. **Đột biến**: Lật bit với xác suất thấp.
#
# ---

# %%
import numpy as np
import math
import random
import matplotlib.pyplot as plt

# Hàm mục tiêu
def fitness_function(x):
    return math.sin(x) + math.cos(x)

# Khởi tạo quần thể
def initialize_population(pop_size, min_val, max_val):
    return [random.uniform(min_val, max_val) for _ in range(pop_size)]

# Lựa chọn (Tournament Selection)
def select_parents(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return (parent1 + parent2) / 2
    return parent1

# Đột biến
def mutate(individual, mutation_rate=0.1, min_val=0, max_val=2*math.pi):
    if random.random() < mutation_rate:
        return random.uniform(min_val, max_val)
    return individual

# Thuật toán di truyền
def genetic_algorithm_example1(pop_size=50, generations=100, min_val=0, max_val=2*math.pi):
    population = initialize_population(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function(x) for x in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(best_fitness)
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents(population, fitness_values)
            parent2 = select_parents(population, fitness_values)
            child = crossover(parent1, parent2)
            child = mutate(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function(x) for x in population])]
        print(f'Thế hệ {generation + 1}: x = {best_individual:.4f}, f(x) = {best_fitness:.4f}')
    
    best_fitness = max([fitness_function(x) for x in population])
    best_individual = population[np.argmax([fitness_function(x) for x in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị f(x) tốt nhất')
    plt.title('Sự thay đổi của f(x) qua các thế hệ')
    plt.show()
    
    return best_individual, best_fitness

# Chạy thuật toán
best_x, best_f = genetic_algorithm_example1()
print(f'\nKết quả cuối cùng: x = {best_x:.4f}, f(x) = {best_f:.4f}')
# Out:
# Thế hệ 1: x = 0.7668, f(x) = 1.4126
# Thế hệ 2: x = 0.7717, f(x) = 1.4140
# Thế hệ 3: x = 0.7870, f(x) = 1.4141
# Thế hệ 4: x = 0.7882, f(x) = 1.4142
# Thế hệ 5: x = 0.7851, f(x) = 1.4142
# Thế hệ 6: x = 0.7856, f(x) = 1.4142
# Thế hệ 7: x = 0.7854, f(x) = 1.4142
# Thế hệ 8: x = 0.7854, f(x) = 1.4142
# Thế hệ 9: x = 0.7854, f(x) = 1.4142
# Thế hệ 10: x = 0.7854, f(x) = 1.4142
# Thế hệ 11: x = 0.7854, f(x) = 1.4142
# Thế hệ 12: x = 0.7854, f(x) = 1.4142
# Thế hệ 13: x = 0.7854, f(x) = 1.4142
# Thế hệ 14: x = 0.7854, f(x) = 1.4142
# Thế hệ 15: x = 0.7854, f(x) = 1.4142
# Thế hệ 16: x = 0.7854, f(x) = 1.4142
# Thế hệ 17: x = 0.7854, f(x) = 1.4142
# Thế hệ 18: x = 0.7854, f(x) = 1.4142
# Thế hệ 19: x = 0.7854, f(x) = 1.4142
# Thế hệ 20: x = 0.7854, f(x) = 1.4142
# Thế hệ 21: x = 0.7854, f(x) = 1.4142
# Thế hệ 22: x = 0.7854, f(x) = 1.4142
# Thế hệ 23: x = 0.7854, f(x) = 1.4142
# Thế hệ 24: x = 0.7854, f(x) = 1.4142
# Thế hệ 25: x = 0.7854, f(x) = 1.4142
# Thế hệ 26: x = 0.7854, f(x) = 1.4142
# Thế hệ 27: x = 0.7854, f(x) = 1.4142
# Thế hệ 28: x = 0.7854, f(x) = 1.4142
# Thế hệ 29: x = 0.7854, f(x) = 1.4142
# Thế hệ 30: x = 0.7854, f(x) = 1.4142
# Thế hệ 31: x = 0.7854, f(x) = 1.4142
# Thế hệ 32: x = 0.7854, f(x) = 1.4142
# Thế hệ 33: x = 0.7854, f(x) = 1.4142
# Thế hệ 34: x = 0.7854, f(x) = 1.4142
# Thế hệ 35: x = 0.7854, f(x) = 1.4142
# Thế hệ 36: x = 0.7854, f(x) = 1.4142
# Thế hệ 37: x = 0.7854, f(x) = 1.4142
# Thế hệ 38: x = 0.7854, f(x) = 1.4142
# Thế hệ 39: x = 0.7854, f(x) = 1.4142
# Thế hệ 40: x = 0.7854, f(x) = 1.4142
# Thế hệ 41: x = 0.7854, f(x) = 1.4142
# Thế hệ 42: x = 0.7854, f(x) = 1.4142
# Thế hệ 43: x = 0.7854, f(x) = 1.4142
# Thế hệ 44: x = 0.7854, f(x) = 1.4142
# Thế hệ 45: x = 0.7854, f(x) = 1.4142
# Thế hệ 46: x = 0.7854, f(x) = 1.4142
# Thế hệ 47: x = 0.7854, f(x) = 1.4142
# Thế hệ 48: x = 0.7854, f(x) = 1.4142
# Thế hệ 49: x = 0.7854, f(x) = 1.4142
# Thế hệ 50: x = 0.7854, f(x) = 1.4142
# Thế hệ 51: x = 0.7854, f(x) = 1.4142
# Thế hệ 52: x = 0.7854, f(x) = 1.4142
# Thế hệ 53: x = 0.7854, f(x) = 1.4142
# Thế hệ 54: x = 0.7854, f(x) = 1.4142
# Thế hệ 55: x = 0.7854, f(x) = 1.4142
# Thế hệ 56: x = 0.7854, f(x) = 1.4142
# Thế hệ 57: x = 0.7854, f(x) = 1.4142
# Thế hệ 58: x = 0.7854, f(x) = 1.4142
# Thế hệ 59: x = 0.7854, f(x) = 1.4142
# Thế hệ 60: x = 0.7854, f(x) = 1.4142
# Thế hệ 61: x = 0.7854, f(x) = 1.4142
# Thế hệ 62: x = 0.7854, f(x) = 1.4142
# Thế hệ 63: x = 0.7854, f(x) = 1.4142
# Thế hệ 64: x = 0.7854, f(x) = 1.4142
# Thế hệ 65: x = 0.7854, f(x) = 1.4142
# Thế hệ 66: x = 0.7854, f(x) = 1.4142
# Thế hệ 67: x = 0.7854, f(x) = 1.4142
# Thế hệ 68: x = 0.7854, f(x) = 1.4142
# Thế hệ 69: x = 0.7854, f(x) = 1.4142
# Thế hệ 70: x = 0.7854, f(x) = 1.4142
# Thế hệ 71: x = 0.7854, f(x) = 1.4142
# Thế hệ 72: x = 0.7854, f(x) = 1.4142
# Thế hệ 73: x = 0.7854, f(x) = 1.4142
# Thế hệ 74: x = 0.7854, f(x) = 1.4142
# Thế hệ 75: x = 0.7854, f(x) = 1.4142
# Thế hệ 76: x = 0.7854, f(x) = 1.4142
# Thế hệ 77: x = 0.7854, f(x) = 1.4142
# Thế hệ 78: x = 0.7854, f(x) = 1.4142
# Thế hệ 79: x = 0.7854, f(x) = 1.4142
# Thế hệ 80: x = 0.7854, f(x) = 1.4142
# Thế hệ 81: x = 0.7854, f(x) = 1.4142
# Thế hệ 82: x = 0.7854, f(x) = 1.4142
# Thế hệ 83: x = 0.7854, f(x) = 1.4142
# Thế hệ 84: x = 0.7854, f(x) = 1.4142
# Thế hệ 85: x = 0.7854, f(x) = 1.4142
# Thế hệ 86: x = 0.7854, f(x) = 1.4142
# Thế hệ 87: x = 0.7854, f(x) = 1.4142
# Thế hệ 88: x = 0.7854, f(x) = 1.4142
# Thế hệ 89: x = 0.7854, f(x) = 1.4142
# Thế hệ 90: x = 0.7854, f(x) = 1.4142
# Thế hệ 91: x = 0.7854, f(x) = 1.4142
# Thế hệ 92: x = 0.7854, f(x) = 1.4142
# Thế hệ 93: x = 0.7854, f(x) = 1.4142
# Thế hệ 94: x = 0.7854, f(x) = 1.4142
# Thế hệ 95: x = 0.7854, f(x) = 1.4142
# Thế hệ 96: x = 0.7854, f(x) = 1.4142
# Thế hệ 97: x = 0.7854, f(x) = 1.4142
# Thế hệ 98: x = 0.7854, f(x) = 1.4142
# Thế hệ 99: x = 0.7854, f(x) = 1.4142
# Thế hệ 100: x = 0.7854, f(x) = 1.4142
# Kết quả cuối cùng: x = 0.7854, f(x) = 1.4142

# %% [markdown]
# # Bài tập 2: Tối ưu hàm $h(x) = \sin(x) + \cos(x)$ bằng Thuật Toán Di Truyền (Genetic Algorithm)
#
# ---
#
# ## Mục tiêu
#
# Tối ưu hàm:
# $$
# h(x) = \sin(x) + \cos(x)
# $$
# trong khoảng:
# $$
# x \in [0, 2\pi]
# $$
#
# > Tìm giá trị $x$ sao cho $h(x)$ đạt **giá trị lớn nhất**.
#
# ---
#
# ## Phân tích nghiệm chính xác
#
# Ta có:
# $$
# h(x) = \sin(x) + \cos(x) = \sqrt{2} \cdot \sin\left(x + \frac{\pi}{4}\right)
# \Rightarrow \max h(x) = \sqrt{2} \approx 1.4142
# $$
#
# Xảy ra khi:
# $$
# x = \frac{\pi}{4} \approx 0.7854
# $$
#
# ---
#
# ##  Ý tưởng thuật toán di truyền (GA)
#
# | Thành phần        | Chi tiết                                                                 |
# |------------------|-------------------------------------------------------------------------|
# | **Mã hóa**        | Dùng chuỗi nhị phân 16 bit để biểu diễn giá trị $x \in [0, 2\pi]$         |
# | **Giải mã**       | Ánh xạ nhị phân sang giá trị thực: $x = 0 + \dfrac{\text{decimal}}{2^{16}-1} \cdot 2\pi$ |
# | **Fitness**       | Chính là $h(x) = \sin(x) + \cos(x)$                                     |
# | **Chọn lọc**      | Roulette Wheel Selection                                                |
# | **Lai ghép**      | 1 điểm cắt với xác suất 0.8                                              |
# | **Đột biến**      | Xác suất 5% (0.05)                                                       |
#
# ---

# %%
# Hàm mục tiêu
def fitness_function_2d(x, y):
    return -(math.sin(x) + math.cos(x))  # Sử dụng dấu âm vì GA tìm max

# Khởi tạo quần thể
def initialize_population_2d(pop_size, min_val, max_val):
    return [(random.uniform(min_val, max_val), random.uniform(min_val, max_val)) for _ in range(pop_size)]

# Lựa chọn
def select_parents_2d(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover_2d(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return ((parent1[0] + parent2[0]) / 2, (parent1[1] + parent2[1]) / 2)
    return parent1

# Đột biến
def mutate_2d(individual, mutation_rate=0.1, min_val=0, max_val=2*math.pi):
    x, y = individual
    if random.random() < mutation_rate:
        x = random.uniform(min_val, max_val)
    if random.random() < mutation_rate:
        y = random.uniform(min_val, max_val)
    return (x, y)

# Thuật toán di truyền
def genetic_algorithm_example2(pop_size=50, generations=100, min_val=0, max_val=2*math.pi):
    population = initialize_population_2d(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function_2d(x, y) for x, y in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(-best_fitness)  # Chuyển về giá trị thực
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents_2d(population, fitness_values)
            parent2 = select_parents_2d(population, fitness_values)
            child = crossover_2d(parent1, parent2)
            child = mutate_2d(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
        print(f'Thế hệ {generation + 1}: (x, y) = ({best_individual[0]:.4f}, {best_individual[1]:.4f}), g(x, y) = {-best_fitness:.4f}')
    
    best_fitness = max([fitness_function_2d(x, y) for x, y in population])
    best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị g(x, y) tốt nhất')
    plt.title('Sự thay đổi của g(x, y) qua các thế hệ')
    plt.show()
    
    return best_individual, -best_fitness

# Chạy thuật toán
best_xy, best_g = genetic_algorithm_example2()
print(f'\nKết quả cuối cùng: (x, y) = ({best_xy[0]:.4f}, {best_xy[1]:.4f}), g(x, y) = {best_g:.4f}')
# Out:
# Thế hệ 1: (x, y) = (3.9313, 4.2874), g(x, y) = -1.4142
# Thế hệ 2: (x, y) = (3.9287, 4.7473), g(x, y) = -1.4142
# Thế hệ 3: (x, y) = (3.9287, 4.7473), g(x, y) = -1.4142
# Thế hệ 4: (x, y) = (3.9287, 5.3416), g(x, y) = -1.4142
# Thế hệ 5: (x, y) = (3.9267, 3.8350), g(x, y) = -1.4142
# Thế hệ 6: (x, y) = (3.9267, 3.8350), g(x, y) = -1.4142
# Thế hệ 7: (x, y) = (3.9271, 3.5279), g(x, y) = -1.4142
# Thế hệ 8: (x, y) = (3.9270, 4.6480), g(x, y) = -1.4142
# Thế hệ 9: (x, y) = (3.9270, 4.3676), g(x, y) = -1.4142
# Thế hệ 10: (x, y) = (3.9270, 4.5352), g(x, y) = -1.4142
# Thế hệ 11: (x, y) = (3.9270, 3.6061), g(x, y) = -1.4142
# Thế hệ 12: (x, y) = (3.9270, 4.2055), g(x, y) = -1.4142
# Thế hệ 13: (x, y) = (3.9270, 4.8359), g(x, y) = -1.4142
# Thế hệ 14: (x, y) = (3.9270, 3.6142), g(x, y) = -1.4142
# Thế hệ 15: (x, y) = (3.9270, 3.6754), g(x, y) = -1.4142
# Thế hệ 16: (x, y) = (3.9270, 3.6142), g(x, y) = -1.4142
# Thế hệ 17: (x, y) = (3.9270, 4.1132), g(x, y) = -1.4142
# Thế hệ 18: (x, y) = (3.9270, 4.1903), g(x, y) = -1.4142
# Thế hệ 19: (x, y) = (3.9270, 3.8249), g(x, y) = -1.4142
# Thế hệ 20: (x, y) = (3.9270, 5.6822), g(x, y) = -1.4142
# Thế hệ 21: (x, y) = (3.9270, 3.9618), g(x, y) = -1.4142
# Thế hệ 22: (x, y) = (3.9270, 4.1255), g(x, y) = -1.4142
# Thế hệ 23: (x, y) = (3.9270, 3.1611), g(x, y) = -1.4142
# Thế hệ 24: (x, y) = (3.9270, 3.9398), g(x, y) = -1.4142
# Thế hệ 25: (x, y) = (3.9270, 3.5616), g(x, y) = -1.4142
# Thế hệ 26: (x, y) = (3.9270, 2.8391), g(x, y) = -1.4142
# Thế hệ 27: (x, y) = (3.9270, 2.8391), g(x, y) = -1.4142
# Thế hệ 28: (x, y) = (3.9270, 3.1282), g(x, y) = -1.4142
# Thế hệ 29: (x, y) = (3.9270, 0.6518), g(x, y) = -1.4142
# Thế hệ 30: (x, y) = (3.9270, 3.8707), g(x, y) = -1.4142
# Thế hệ 31: (x, y) = (3.9270, 1.9466), g(x, y) = -1.4142
# Thế hệ 32: (x, y) = (3.9270, 5.0817), g(x, y) = -1.4142
# Thế hệ 33: (x, y) = (3.9270, 1.6236), g(x, y) = -1.4142
# Thế hệ 34: (x, y) = (3.9270, 2.1407), g(x, y) = -1.4142
# Thế hệ 35: (x, y) = (3.9270, 2.4894), g(x, y) = -1.4142
# Thế hệ 36: (x, y) = (3.9270, 1.7733), g(x, y) = -1.4142
# Thế hệ 37: (x, y) = (3.9270, 2.6552), g(x, y) = -1.4142
# Thế hệ 38: (x, y) = (3.9270, 2.4511), g(x, y) = -1.4142
# Thế hệ 39: (x, y) = (3.9270, 3.4672), g(x, y) = -1.4142
# Thế hệ 40: (x, y) = (3.9270, 0.0631), g(x, y) = -1.4142
# Thế hệ 41: (x, y) = (3.9270, 0.0631), g(x, y) = -1.4142
# Thế hệ 42: (x, y) = (3.9270, 2.5372), g(x, y) = -1.4142
# Thế hệ 43: (x, y) = (3.9270, 3.4672), g(x, y) = -1.4142
# Thế hệ 44: (x, y) = (3.9270, 2.9044), g(x, y) = -1.4142
# Thế hệ 45: (x, y) = (3.9270, 3.0501), g(x, y) = -1.4142
# Thế hệ 46: (x, y) = (3.9270, 2.9502), g(x, y) = -1.4142
# Thế hệ 47: (x, y) = (3.9270, 2.5258), g(x, y) = -1.4142
# Thế hệ 48: (x, y) = (3.9270, 5.9402), g(x, y) = -1.4142
# Thế hệ 49: (x, y) = (3.9270, 2.6438), g(x, y) = -1.4142
# Thế hệ 50: (x, y) = (3.9270, 2.8020), g(x, y) = -1.4142
# Thế hệ 51: (x, y) = (3.9270, 1.2246), g(x, y) = -1.4142
# Thế hệ 52: (x, y) = (3.9270, 2.6203), g(x, y) = -1.4142
# Thế hệ 53: (x, y) = (3.9270, 2.6203), g(x, y) = -1.4142
# Thế hệ 54: (x, y) = (3.9270, 0.6777), g(x, y) = -1.4142
# Thế hệ 55: (x, y) = (3.9270, 2.2442), g(x, y) = -1.4142
# Thế hệ 56: (x, y) = (3.9270, 2.8352), g(x, y) = -1.4142
# Thế hệ 57: (x, y) = (3.9270, 0.5583), g(x, y) = -1.4142
# Thế hệ 58: (x, y) = (3.9270, 3.3633), g(x, y) = -1.4142
# Thế hệ 59: (x, y) = (3.9270, 3.0924), g(x, y) = -1.4142
# Thế hệ 60: (x, y) = (3.9270, 3.8514), g(x, y) = -1.4142
# Thế hệ 61: (x, y) = (3.9270, 3.8514), g(x, y) = -1.4142
# Thế hệ 62: (x, y) = (3.9270, 1.8273), g(x, y) = -1.4142
# Thế hệ 63: (x, y) = (3.9270, 3.5582), g(x, y) = -1.4142
# Thế hệ 64: (x, y) = (3.9270, 3.7439), g(x, y) = -1.4142
# Thế hệ 65: (x, y) = (3.9270, 3.7882), g(x, y) = -1.4142
# Thế hệ 66: (x, y) = (3.9270, 5.5510), g(x, y) = -1.4142
# Thế hệ 67: (x, y) = (3.9270, 2.3798), g(x, y) = -1.4142
# Thế hệ 68: (x, y) = (3.9270, 3.1278), g(x, y) = -1.4142
# Thế hệ 69: (x, y) = (3.9270, 2.4824), g(x, y) = -1.4142
# Thế hệ 70: (x, y) = (3.9270, 2.9487), g(x, y) = -1.4142
# Thế hệ 71: (x, y) = (3.9270, 2.5337), g(x, y) = -1.4142
# Thế hệ 72: (x, y) = (3.9270, 2.1504), g(x, y) = -1.4142
# Thế hệ 73: (x, y) = (3.9270, 2.9309), g(x, y) = -1.4142
# Thế hệ 74: (x, y) = (3.9270, 2.2616), g(x, y) = -1.4142
# Thế hệ 75: (x, y) = (3.9270, 2.4734), g(x, y) = -1.4142
# Thế hệ 76: (x, y) = (3.9270, 2.2848), g(x, y) = -1.4142
# Thế hệ 77: (x, y) = (3.9270, 3.7505), g(x, y) = -1.4142
# Thế hệ 78: (x, y) = (3.9270, 2.2848), g(x, y) = -1.4142
# Thế hệ 79: (x, y) = (3.9270, 3.0176), g(x, y) = -1.4142
# Thế hệ 80: (x, y) = (3.9270, 3.0176), g(x, y) = -1.4142
# Thế hệ 81: (x, y) = (3.9270, 2.8045), g(x, y) = -1.4142
# Thế hệ 82: (x, y) = (3.9270, 2.9473), g(x, y) = -1.4142
# Thế hệ 83: (x, y) = (3.9270, 3.3121), g(x, y) = -1.4142
# Thế hệ 84: (x, y) = (3.9270, 3.3121), g(x, y) = -1.4142
# Thế hệ 85: (x, y) = (3.9270, 3.7697), g(x, y) = -1.4142
# Thế hệ 86: (x, y) = (3.9270, 2.3410), g(x, y) = -1.4142
# Thế hệ 87: (x, y) = (3.9270, 5.0257), g(x, y) = -1.4142
# Thế hệ 88: (x, y) = (3.9270, 2.0843), g(x, y) = -1.4142
# Thế hệ 89: (x, y) = (3.9270, 3.1470), g(x, y) = -1.4142
# Thế hệ 90: (x, y) = (3.9270, 4.1439), g(x, y) = -1.4142
# Thế hệ 91: (x, y) = (3.9270, 3.6215), g(x, y) = -1.4142
# Thế hệ 92: (x, y) = (3.9270, 4.0740), g(x, y) = -1.4142
# Thế hệ 93: (x, y) = (3.9270, 3.1295), g(x, y) = -1.4142
# Thế hệ 94: (x, y) = (3.9270, 1.6246), g(x, y) = -1.4142
# Thế hệ 95: (x, y) = (3.9270, 2.1346), g(x, y) = -1.4142
# Thế hệ 96: (x, y) = (3.9270, 3.4848), g(x, y) = -1.4142
# Thế hệ 97: (x, y) = (3.9270, 3.1369), g(x, y) = -1.4142
# Thế hệ 98: (x, y) = (3.9270, 2.3266), g(x, y) = -1.4142
# Thế hệ 99: (x, y) = (3.9270, 3.2477), g(x, y) = -1.4142
# Thế hệ 100: (x, y) = (3.9270, 5.2681), g(x, y) = -1.4142
# Kết quả cuối cùng: (x, y) = (3.9270, 5.2681), g(x, y) = -1.4142

# %% [markdown]
# # Bài Tập 3
#
# # Thay đổi tham số thuật toán di truyền và phân tích tốc độ hội tụ
#
# **Mục tiêu:** Thử thay đổi các tham số chính của thuật toán di truyền gồm:
#
# - Kích thước quần thể: `pop_size`
# - Số thế hệ: `generations`
# - Tỷ lệ đột biến: `mutation_rate`
# - Tỷ lệ lai ghép: `crossover_rate`
#
# và phân tích ảnh hưởng của từng tham số đến tốc độ hội tụ của thuật toán.
#
# ---
#
# ## Các tham số và vai trò
#
# | Tham số         | Ý nghĩa                                  | Ảnh hưởng chính                                                                                         |
# |-----------------|-----------------------------------------|--------------------------------------------------------------------------------------------------------|
# | `pop_size`      | Số cá thể trong quần thể                 | Quần thể lớn giúp khám phá không gian tìm kiếm tốt hơn nhưng tốn nhiều thời gian tính toán. Quần thể nhỏ hội tụ nhanh nhưng dễ bị kẹt cực trị cục bộ. |
# | `generations`   | Số vòng lặp của thuật toán               | Số thế hệ càng nhiều thì thuật toán có nhiều cơ hội cải thiện nghiệm, tuy nhiên thời gian chạy cũng tăng. |
# | `mutation_rate` | Xác suất đột biến mỗi bit                | Đột biến cao giúp tăng đa dạng gene, tránh bị kẹt trong cực trị cục bộ, nhưng nếu quá cao làm quá trình tìm kiếm nhiễu loạn. |
# | `crossover_rate`| Xác suất lai ghép giữa hai cá thể       | Lai ghép giúp phối hợp gen tốt, tăng khả năng tìm nghiệm tốt. Nếu quá thấp, quần thể kém đa dạng; quá cao có thể phá hủy cấu trúc tốt của cá thể. |
#
# ---
#
# ## Phân tích ảnh hưởng
#
# - **`pop_size`**: Kích thước quần thể lớn giúp tìm kiếm toàn cục tốt hơn nhưng chậm hơn, kích thước nhỏ làm thuật toán hội tụ nhanh nhưng dễ mắc kẹt.
# - **`generations`**: Số thế hệ lớn tăng khả năng cải tiến kết quả nhưng làm tăng thời gian tính toán.
# - **`mutation_rate`**: Tỷ lệ đột biến vừa phải giúp duy trì đa dạng di truyền, tránh kẹt cục bộ; quá cao hoặc quá thấp đều làm giảm hiệu quả.
# - **`crossover_rate`**: Tỷ lệ lai ghép hợp lý giúp khai thác tốt thông tin di truyền, tăng hiệu quả hội tụ.
#
# ---

# %%
# Hàm mục tiêu
def fitness_function_2d(x, y):
    return -(math.sin(x) + math.cos(x))  # Sử dụng dấu âm vì GA tìm max

# Khởi tạo quần thể
def initialize_population_2d(pop_size, min_val, max_val):
    return [(random.uniform(min_val, max_val), random.uniform(min_val, max_val)) for _ in range(pop_size)]

# Lựa chọn
def select_parents_2d(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover_2d(parent1, parent2, crossover_rate=0.9):
    if random.random() < crossover_rate:
        return ((parent1[0] + parent2[0]) / 2, (parent1[1] + parent2[1]) / 2)
    return parent1

# Đột biến
def mutate_2d(individual, mutation_rate=0.5, min_val=0, max_val=2*math.pi):
    x, y = individual
    if random.random() < mutation_rate:
        x = random.uniform(min_val, max_val)
    if random.random() < mutation_rate:
        y = random.uniform(min_val, max_val)
    return (x, y)

# Thuật toán di truyền
def genetic_algorithm_example2(pop_size=100, generations=150, min_val=0, max_val=2*math.pi):
    population = initialize_population_2d(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function_2d(x, y) for x, y in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(-best_fitness)  # Chuyển về giá trị thực
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents_2d(population, fitness_values)
            parent2 = select_parents_2d(population, fitness_values)
            child = crossover_2d(parent1, parent2)
            child = mutate_2d(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
        print(f'Thế hệ {generation + 1}: (x, y) = ({best_individual[0]:.4f}, {best_individual[1]:.4f}), g(x, y) = {-best_fitness:.4f}')
    
    best_fitness = max([fitness_function_2d(x, y) for x, y in population])
    best_individual = population[np.argmax([fitness_function_2d(x, y) for x, y in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị g(x, y) tốt nhất')
    plt.title('Sự thay đổi của g(x, y) qua các thế hệ')
    plt.show()
    
    return best_individual, -best_fitness

# Chạy thuật toán
best_xy, best_g = genetic_algorithm_example2()
print(f'\nKết quả cuối cùng: (x, y) = ({best_xy[0]:.4f}, {best_xy[1]:.4f}), g(x, y) = {best_g:.4f}')
# Out:
# Thế hệ 1: (x, y) = (3.9341, 2.8314), g(x, y) = -1.4142
# Thế hệ 2: (x, y) = (3.9233, 1.9626), g(x, y) = -1.4142
# Thế hệ 3: (x, y) = (3.9259, 1.7012), g(x, y) = -1.4142
# Thế hệ 4: (x, y) = (3.9241, 3.6298), g(x, y) = -1.4142
# Thế hệ 5: (x, y) = (3.9276, 4.2148), g(x, y) = -1.4142
# Thế hệ 6: (x, y) = (3.9260, 4.5918), g(x, y) = -1.4142
# Thế hệ 7: (x, y) = (3.9241, 2.4556), g(x, y) = -1.4142
# Thế hệ 8: (x, y) = (3.9272, 3.7951), g(x, y) = -1.4142
# Thế hệ 9: (x, y) = (3.9321, 6.2240), g(x, y) = -1.4142
# Thế hệ 10: (x, y) = (3.9232, 5.4475), g(x, y) = -1.4142
# Thế hệ 11: (x, y) = (3.9275, 1.1834), g(x, y) = -1.4142
# Thế hệ 12: (x, y) = (3.9246, 3.5025), g(x, y) = -1.4142
# Thế hệ 13: (x, y) = (3.9273, 3.1675), g(x, y) = -1.4142
# Thế hệ 14: (x, y) = (3.9256, 0.7025), g(x, y) = -1.4142
# Thế hệ 15: (x, y) = (3.9279, 5.1229), g(x, y) = -1.4142
# Thế hệ 16: (x, y) = (3.9260, 4.5422), g(x, y) = -1.4142
# Thế hệ 17: (x, y) = (3.9241, 5.4762), g(x, y) = -1.4142
# Thế hệ 18: (x, y) = (3.9241, 5.4762), g(x, y) = -1.4142
# Thế hệ 19: (x, y) = (3.9293, 3.2829), g(x, y) = -1.4142
# Thế hệ 20: (x, y) = (3.9267, 5.0892), g(x, y) = -1.4142
# Thế hệ 21: (x, y) = (3.9260, 6.1721), g(x, y) = -1.4142
# Thế hệ 22: (x, y) = (3.9291, 3.9449), g(x, y) = -1.4142
# Thế hệ 23: (x, y) = (3.9264, 3.3702), g(x, y) = -1.4142
# Thế hệ 24: (x, y) = (3.9260, 5.3095), g(x, y) = -1.4142
# Thế hệ 25: (x, y) = (3.9228, 2.2963), g(x, y) = -1.4142
# Thế hệ 26: (x, y) = (3.9228, 1.1621), g(x, y) = -1.4142
# Thế hệ 27: (x, y) = (3.9264, 3.3513), g(x, y) = -1.4142
# Thế hệ 28: (x, y) = (3.9256, 4.2537), g(x, y) = -1.4142
# Thế hệ 29: (x, y) = (3.9302, 1.8520), g(x, y) = -1.4142
# Thế hệ 30: (x, y) = (3.9281, 3.5330), g(x, y) = -1.4142
# Thế hệ 31: (x, y) = (3.9261, 4.1523), g(x, y) = -1.4142
# Thế hệ 32: (x, y) = (3.9279, 5.3350), g(x, y) = -1.4142
# Thế hệ 33: (x, y) = (3.9271, 2.6099), g(x, y) = -1.4142
# Thế hệ 34: (x, y) = (3.9271, 2.6099), g(x, y) = -1.4142
# Thế hệ 35: (x, y) = (3.9265, 2.7767), g(x, y) = -1.4142
# Thế hệ 36: (x, y) = (3.9267, 1.7101), g(x, y) = -1.4142
# Thế hệ 37: (x, y) = (3.9258, 2.6027), g(x, y) = -1.4142
# Thế hệ 38: (x, y) = (3.9260, 3.0592), g(x, y) = -1.4142
# Thế hệ 39: (x, y) = (3.9271, 0.0627), g(x, y) = -1.4142
# Thế hệ 40: (x, y) = (3.9263, 1.1597), g(x, y) = -1.4142
# Thế hệ 41: (x, y) = (3.9259, 3.0588), g(x, y) = -1.4142
# Thế hệ 42: (x, y) = (3.9269, 0.6786), g(x, y) = -1.4142
# Thế hệ 43: (x, y) = (3.9276, 3.7847), g(x, y) = -1.4142
# Thế hệ 44: (x, y) = (3.9276, 3.7847), g(x, y) = -1.4142
# Thế hệ 45: (x, y) = (3.9267, 4.6222), g(x, y) = -1.4142
# Thế hệ 46: (x, y) = (3.9270, 3.1235), g(x, y) = -1.4142
# Thế hệ 47: (x, y) = (3.9258, 4.1838), g(x, y) = -1.4142
# Thế hệ 48: (x, y) = (3.9283, 3.7450), g(x, y) = -1.4142
# Thế hệ 49: (x, y) = (3.9255, 0.2146), g(x, y) = -1.4142
# Thế hệ 50: (x, y) = (3.9295, 1.1500), g(x, y) = -1.4142
# Thế hệ 51: (x, y) = (3.9241, 1.5426), g(x, y) = -1.4142
# Thế hệ 52: (x, y) = (3.9287, 1.4515), g(x, y) = -1.4142
# Thế hệ 53: (x, y) = (3.9219, 5.3313), g(x, y) = -1.4142
# Thế hệ 54: (x, y) = (3.9324, 3.4788), g(x, y) = -1.4142
# Thế hệ 55: (x, y) = (3.9253, 3.4009), g(x, y) = -1.4142
# Thế hệ 56: (x, y) = (3.9253, 4.4066), g(x, y) = -1.4142
# Thế hệ 57: (x, y) = (3.9288, 2.4641), g(x, y) = -1.4142
# Thế hệ 58: (x, y) = (3.9322, 4.7748), g(x, y) = -1.4142
# Thế hệ 59: (x, y) = (3.9264, 5.3324), g(x, y) = -1.4142
# Thế hệ 60: (x, y) = (3.9280, 0.5315), g(x, y) = -1.4142
# Thế hệ 61: (x, y) = (3.9251, 3.0150), g(x, y) = -1.4142
# Thế hệ 62: (x, y) = (3.9229, 5.1204), g(x, y) = -1.4142
# Thế hệ 63: (x, y) = (3.9259, 5.0245), g(x, y) = -1.4142
# Thế hệ 64: (x, y) = (3.9258, 3.9270), g(x, y) = -1.4142
# Thế hệ 65: (x, y) = (3.9240, 5.7209), g(x, y) = -1.4142
# Thế hệ 66: (x, y) = (3.9292, 3.9456), g(x, y) = -1.4142
# Thế hệ 67: (x, y) = (3.9285, 3.9699), g(x, y) = -1.4142
# Thế hệ 68: (x, y) = (3.9285, 0.7194), g(x, y) = -1.4142
# Thế hệ 69: (x, y) = (3.9249, 4.0313), g(x, y) = -1.4142
# Thế hệ 70: (x, y) = (3.9228, 1.5944), g(x, y) = -1.4142
# Thế hệ 71: (x, y) = (3.9278, 0.5561), g(x, y) = -1.4142
# Thế hệ 72: (x, y) = (3.9303, 2.3767), g(x, y) = -1.4142
# Thế hệ 73: (x, y) = (3.9268, 2.7531), g(x, y) = -1.4142
# Thế hệ 74: (x, y) = (3.9268, 2.7531), g(x, y) = -1.4142
# Thế hệ 75: (x, y) = (3.9274, 5.3304), g(x, y) = -1.4142
# Thế hệ 76: (x, y) = (3.9264, 0.9871), g(x, y) = -1.4142
# Thế hệ 77: (x, y) = (3.9268, 6.2482), g(x, y) = -1.4142
# Thế hệ 78: (x, y) = (3.9268, 6.2482), g(x, y) = -1.4142
# Thế hệ 79: (x, y) = (3.9267, 4.2995), g(x, y) = -1.4142
# Thế hệ 80: (x, y) = (3.9271, 3.9388), g(x, y) = -1.4142
# Thế hệ 81: (x, y) = (3.9271, 3.9388), g(x, y) = -1.4142
# Thế hệ 82: (x, y) = (3.9276, 1.5131), g(x, y) = -1.4142
# Thế hệ 83: (x, y) = (3.9269, 5.8394), g(x, y) = -1.4142
# Thế hệ 84: (x, y) = (3.9272, 4.1359), g(x, y) = -1.4142
# Thế hệ 85: (x, y) = (3.9270, 3.7831), g(x, y) = -1.4142
# Thế hệ 86: (x, y) = (3.9270, 3.7831), g(x, y) = -1.4142
# Thế hệ 87: (x, y) = (3.9270, 4.2893), g(x, y) = -1.4142
# Thế hệ 88: (x, y) = (3.9291, 5.8727), g(x, y) = -1.4142
# Thế hệ 89: (x, y) = (3.9278, 2.6686), g(x, y) = -1.4142
# Thế hệ 90: (x, y) = (3.9355, 1.1831), g(x, y) = -1.4142
# Thế hệ 91: (x, y) = (3.9355, 1.1831), g(x, y) = -1.4142
# Thế hệ 92: (x, y) = (3.9301, 1.4881), g(x, y) = -1.4142
# Thế hệ 93: (x, y) = (3.9228, 3.7021), g(x, y) = -1.4142
# Thế hệ 94: (x, y) = (3.9262, 2.2419), g(x, y) = -1.4142
# Thế hệ 95: (x, y) = (3.9277, 0.1574), g(x, y) = -1.4142
# Thế hệ 96: (x, y) = (3.9222, 5.0029), g(x, y) = -1.4142
# Thế hệ 97: (x, y) = (3.9224, 1.5742), g(x, y) = -1.4142
# Thế hệ 98: (x, y) = (3.9274, 2.2300), g(x, y) = -1.4142
# Thế hệ 99: (x, y) = (3.9272, 5.3652), g(x, y) = -1.4142
# Thế hệ 100: (x, y) = (3.9272, 4.1929), g(x, y) = -1.4142
# Thế hệ 101: (x, y) = (3.9272, 4.1929), g(x, y) = -1.4142
# Thế hệ 102: (x, y) = (3.9287, 2.8399), g(x, y) = -1.4142
# Thế hệ 103: (x, y) = (3.9296, 4.0838), g(x, y) = -1.4142
# Thế hệ 104: (x, y) = (3.9310, 2.4042), g(x, y) = -1.4142
# Thế hệ 105: (x, y) = (3.9254, 2.9465), g(x, y) = -1.4142
# Thế hệ 106: (x, y) = (3.9331, 5.0366), g(x, y) = -1.4142
# Thế hệ 107: (x, y) = (3.9313, 5.9346), g(x, y) = -1.4142
# Thế hệ 108: (x, y) = (3.9175, 2.4892), g(x, y) = -1.4142
# Thế hệ 109: (x, y) = (3.9161, 2.1320), g(x, y) = -1.4141
# Thế hệ 110: (x, y) = (3.9339, 1.7984), g(x, y) = -1.4141
# Thế hệ 111: (x, y) = (3.9252, 4.4205), g(x, y) = -1.4142
# Thế hệ 112: (x, y) = (3.9301, 3.1347), g(x, y) = -1.4142
# Thế hệ 113: (x, y) = (3.9251, 4.2478), g(x, y) = -1.4142
# Thế hệ 114: (x, y) = (3.9258, 1.8797), g(x, y) = -1.4142
# Thế hệ 115: (x, y) = (3.9270, 0.6449), g(x, y) = -1.4142
# Thế hệ 116: (x, y) = (3.9270, 2.0928), g(x, y) = -1.4142
# Thế hệ 117: (x, y) = (3.9264, 5.9292), g(x, y) = -1.4142
# Thế hệ 118: (x, y) = (3.9262, 1.9551), g(x, y) = -1.4142
# Thế hệ 119: (x, y) = (3.9267, 3.0664), g(x, y) = -1.4142
# Thế hệ 120: (x, y) = (3.9281, 1.9889), g(x, y) = -1.4142
# Thế hệ 121: (x, y) = (3.9270, 4.2390), g(x, y) = -1.4142
# Thế hệ 122: (x, y) = (3.9215, 3.1648), g(x, y) = -1.4142
# Thế hệ 123: (x, y) = (3.9240, 3.4771), g(x, y) = -1.4142
# Thế hệ 124: (x, y) = (3.9272, 0.8227), g(x, y) = -1.4142
# Thế hệ 125: (x, y) = (3.9280, 3.7960), g(x, y) = -1.4142
# Thế hệ 126: (x, y) = (3.9236, 0.0076), g(x, y) = -1.4142
# Thế hệ 127: (x, y) = (3.9251, 4.1657), g(x, y) = -1.4142
# Thế hệ 128: (x, y) = (3.9273, 2.9840), g(x, y) = -1.4142
# Thế hệ 129: (x, y) = (3.9261, 4.6443), g(x, y) = -1.4142
# Thế hệ 130: (x, y) = (3.9271, 3.4052), g(x, y) = -1.4142
# Thế hệ 131: (x, y) = (3.9269, 0.3676), g(x, y) = -1.4142
# Thế hệ 132: (x, y) = (3.9278, 2.2171), g(x, y) = -1.4142
# Thế hệ 133: (x, y) = (3.9255, 1.1047), g(x, y) = -1.4142
# Thế hệ 134: (x, y) = (3.9235, 1.1922), g(x, y) = -1.4142
# Thế hệ 135: (x, y) = (3.9260, 4.8852), g(x, y) = -1.4142
# Thế hệ 136: (x, y) = (3.9266, 3.8530), g(x, y) = -1.4142
# Thế hệ 137: (x, y) = (3.9271, 1.7350), g(x, y) = -1.4142
# Thế hệ 138: (x, y) = (3.9274, 5.6159), g(x, y) = -1.4142
# Thế hệ 139: (x, y) = (3.9285, 3.4035), g(x, y) = -1.4142
# Thế hệ 140: (x, y) = (3.9266, 3.7890), g(x, y) = -1.4142
# Thế hệ 141: (x, y) = (3.9266, 1.9665), g(x, y) = -1.4142
# Thế hệ 142: (x, y) = (3.9274, 3.5226), g(x, y) = -1.4142
# Thế hệ 143: (x, y) = (3.9270, 2.5600), g(x, y) = -1.4142
# Thế hệ 144: (x, y) = (3.9275, 0.8981), g(x, y) = -1.4142
# Thế hệ 145: (x, y) = (3.9274, 4.6225), g(x, y) = -1.4142
# Thế hệ 146: (x, y) = (3.9274, 1.1982), g(x, y) = -1.4142
# Thế hệ 147: (x, y) = (3.9271, 3.0047), g(x, y) = -1.4142
# Thế hệ 148: (x, y) = (3.9272, 2.4684), g(x, y) = -1.4142
# Thế hệ 149: (x, y) = (3.9272, 2.4684), g(x, y) = -1.4142
# Thế hệ 150: (x, y) = (3.9270, 6.2689), g(x, y) = -1.4142
# Kết quả cuối cùng: (x, y) = (3.9270, 6.2689), g(x, y) = -1.4142

# %% [markdown]
# # Bài tập 4
# # Cải tiến thuật toán – Thêm phương pháp lựa chọn khác và so sánh hiệu quả
#
# ---
#
# ## Mục tiêu
#
# - Thêm phương pháp lựa chọn mới vào thuật toán di truyền, ví dụ như **Roulette Wheel Selection** (Lựa chọn bánh xe con quay).
# - So sánh hiệu quả của phương pháp lựa chọn mới với phương pháp cũ (ví dụ: Chọn ngẫu nhiên, Tournament Selection, v.v.).
# - Phân tích ảnh hưởng của phương pháp lựa chọn đến tốc độ hội tụ và chất lượng nghiệm.
#
# ---
#
# ##  Các phương pháp lựa chọn phổ biến
#
# | Phương pháp                | Mô tả                                                                                   | Ưu điểm                              | Nhược điểm                          |
# |----------------------------|-----------------------------------------------------------------------------------------|------------------------------------|-----------------------------------|
# | Chọn ngẫu nhiên (Random)   | Chọn cá thể ngẫu nhiên trong quần thể                                                   | Đơn giản, nhanh                    | Không ưu tiên cá thể tốt hơn      |
# | Roulette Wheel Selection    | Chọn theo xác suất tỷ lệ thuận với độ thích nghi (fitness)                              | Dễ dàng, ưu tiên cá thể tốt        | Dễ bị ảnh hưởng bởi cá thể quá mạnh|
# | Tournament Selection        | Chọn ngẫu nhiên một số cá thể, chọn cá thể tốt nhất trong nhóm                          | Kiểm soát đa dạng tốt              | Cần chọn kích thước nhóm phù hợp  |
#
# ---
#
# ##  Ý tưởng cải tiến
#
# 1. Cài đặt thêm phương pháp **Roulette Wheel Selection** trong thuật toán di truyền.
# 2. Chạy thử với cùng bộ tham số trên các phương pháp lựa chọn khác nhau.
# 3. So sánh kết quả về:
#    - Tốc độ hội tụ (số thế hệ cần để đạt nghiệm tốt).
#    - Giá trị nghiệm tốt nhất đạt được.
# 4. Phân tích ưu – nhược điểm từng phương pháp trong thực tế.
#
# ---
#
# ##  Kết quả và phân tích
#
# - Phương pháp **Roulette Wheel** thường giúp tăng tốc độ hội tụ nhờ ưu tiên cá thể tốt.
# - Tuy nhiên có thể làm giảm đa dạng gen nếu cá thể ưu tú chiếm ưu thế quá lớn, dễ rơi vào cực trị cục bộ.
# - Phương pháp **Tournament** kiểm soát tốt sự đa dạng nhưng có thể chậm hơn trong một số trường hợp.
# - Phương pháp **Random** đơn giản nhưng ít hiệu quả trong tối ưu nâng cao.
#
# ---

# %%
import numpy as np
import math
import random
import matplotlib.pyplot as plt

# Hàm mục tiêu
def fitness_function(x):
    return math.sin(x) + math.cos(x)

# Khởi tạo quần thể
def initialize_population(pop_size, min_val, max_val):
    return [random.uniform(min_val, max_val) for _ in range(pop_size)]

# Lựa chọn (Tournament Selection)
def tournament_selection(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lựa chọn (Roulette Wheel Selection)
def roulette_wheel_selection(population, fitness_values):
    total_fitness = sum(fitness_values)
    if total_fitness == 0:
        return random.choice(population)
    
    pick = random.uniform(0, total_fitness)
    current = 0
    for individual, fitness in zip(population, fitness_values):
        current += fitness
        if current >= pick:
            return individual
    return population[-1]

# Lai ghép
def crossover(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return (parent1 + parent2) / 2
    return parent1

# Đột biến
def mutate(individual, mutation_rate=0.1, min_val=0, max_val=2*math.pi):
    if random.random() < mutation_rate:
        return random.uniform(min_val, max_val)
    return individual

# Thuật toán di truyền
def genetic_algorithm_example1(pop_size=50, generations=100, min_val=0, max_val=2*math.pi, 
                                selection_method='tournament', tournament_size=3, mutation_rate=0.1, crossover_rate=0.8):
    population = initialize_population(pop_size, min_val, max_val)
    best_fitness_history = []
    
    for generation in range(generations):
        fitness_values = [fitness_function(x) for x in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(best_fitness)
        
        new_population = []
        for _ in range(pop_size):
            if selection_method == 'tournament':
                parent1 = tournament_selection(population, fitness_values, tournament_size)
                parent2 = tournament_selection(population, fitness_values, tournament_size)
            elif selection_method == 'roulette':
                parent1 = roulette_wheel_selection(population, fitness_values)
                parent2 = roulette_wheel_selection(population, fitness_values)
            else:
                raise ValueError("Lựa chọn selection_method phải là 'tournament' hoặc 'roulette'")
            
            child = crossover(parent1, parent2, crossover_rate)
            child = mutate(child, mutation_rate, min_val, max_val)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function(x) for x in population])]
        print(f'Thế hệ {generation + 1}: x = {best_individual:.4f}, f(x) = {best_fitness:.4f}')
    
    best_fitness = max([fitness_function(x) for x in population])
    best_individual = population[np.argmax([fitness_function(x) for x in population])]
    
    # Trực quan hóa
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị f(x) tốt nhất')
    plt.title(f'Sự thay đổi của f(x) ({selection_method.capitalize()} Selection)')
    plt.show()
    
    return best_individual, best_fitness

# Chạy thuật toán với Roulette Wheel Selection
best_x, best_f = genetic_algorithm_example1(selection_method='roulette')
print(f'\nKết quả cuối cùng (Roulette): x = {best_x:.4f}, f(x) = {best_f:.4f}')
# Out:
# Thế hệ 1: x = 0.9888, f(x) = 1.4083
# Thế hệ 2: x = 0.9888, f(x) = 1.3851
# Thế hệ 3: x = 0.9888, f(x) = 1.3851
# Thế hệ 4: x = 0.9888, f(x) = 1.3851
# Thế hệ 5: x = 0.9888, f(x) = 1.3851
# Thế hệ 6: x = 0.8323, f(x) = 1.3851
# Thế hệ 7: x = 0.8323, f(x) = 1.4127
# Thế hệ 8: x = 0.8323, f(x) = 1.4127
# Thế hệ 9: x = 0.9106, f(x) = 1.4127
# Thế hệ 10: x = 0.7841, f(x) = 1.4032
# Thế hệ 11: x = 0.7689, f(x) = 1.4142
# Thế hệ 12: x = 0.7664, f(x) = 1.4140
# Thế hệ 13: x = 0.7664, f(x) = 1.4140
# Thế hệ 14: x = 0.7360, f(x) = 1.4140
# Thế hệ 15: x = 0.8144, f(x) = 1.4125
# Thế hệ 16: x = 0.9016, f(x) = 1.4136
# Thế hệ 17: x = 0.7349, f(x) = 1.4047
# Thế hệ 18: x = 0.7745, f(x) = 1.4124
# Thế hệ 19: x = 0.6908, f(x) = 1.4141
# Thế hệ 20: x = 0.8160, f(x) = 1.4079
# Thế hệ 21: x = 0.8221, f(x) = 1.4135
# Thế hệ 22: x = 0.7819, f(x) = 1.4133
# Thế hệ 23: x = 0.7887, f(x) = 1.4142
# Thế hệ 24: x = 0.7902, f(x) = 1.4142
# Thế hệ 25: x = 0.7551, f(x) = 1.4142
# Thế hệ 26: x = 0.8139, f(x) = 1.4136
# Thế hệ 27: x = 0.8243, f(x) = 1.4136
# Thế hệ 28: x = 0.8621, f(x) = 1.4131
# Thế hệ 29: x = 0.8621, f(x) = 1.4101
# Thế hệ 30: x = 0.7883, f(x) = 1.4101
# Thế hệ 31: x = 0.7930, f(x) = 1.4142
# Thế hệ 32: x = 0.7930, f(x) = 1.4142
# Thế hệ 33: x = 0.7869, f(x) = 1.4142
# Thế hệ 34: x = 0.7951, f(x) = 1.4142
# Thế hệ 35: x = 0.7843, f(x) = 1.4141
# Thế hệ 36: x = 0.7852, f(x) = 1.4142
# Thế hệ 37: x = 0.7923, f(x) = 1.4142
# Thế hệ 38: x = 0.7857, f(x) = 1.4142
# Thế hệ 39: x = 0.7857, f(x) = 1.4142
# Thế hệ 40: x = 0.7984, f(x) = 1.4142
# Thế hệ 41: x = 0.8178, f(x) = 1.4141
# Thế hệ 42: x = 0.8250, f(x) = 1.4135
# Thế hệ 43: x = 0.8292, f(x) = 1.4131
# Thế hệ 44: x = 0.8328, f(x) = 1.4129
# Thế hệ 45: x = 0.8198, f(x) = 1.4126
# Thế hệ 46: x = 0.8930, f(x) = 1.4134
# Thế hệ 47: x = 0.8930, f(x) = 1.4060
# Thế hệ 48: x = 0.7502, f(x) = 1.4060
# Thế hệ 49: x = 0.7969, f(x) = 1.4133
# Thế hệ 50: x = 0.7653, f(x) = 1.4141
# Thế hệ 51: x = 0.7540, f(x) = 1.4139
# Thế hệ 52: x = 0.8596, f(x) = 1.4135
# Thế hệ 53: x = 0.8596, f(x) = 1.4103
# Thế hệ 54: x = 0.7498, f(x) = 1.4103
# Thế hệ 55: x = 0.7680, f(x) = 1.4133
# Thế hệ 56: x = 0.7779, f(x) = 1.4140
# Thế hệ 57: x = 0.8079, f(x) = 1.4142
# Thế hệ 58: x = 0.8440, f(x) = 1.4139
# Thế hệ 59: x = 0.8440, f(x) = 1.4118
# Thế hệ 60: x = 0.9207, f(x) = 1.4118
# Thế hệ 61: x = 0.7105, f(x) = 1.4013
# Thế hệ 62: x = 0.8434, f(x) = 1.4102
# Thế hệ 63: x = 0.9625, f(x) = 1.4118
# Thế hệ 64: x = 0.7925, f(x) = 1.3921
# Thế hệ 65: x = 0.7436, f(x) = 1.4142
# Thế hệ 66: x = 0.7766, f(x) = 1.4130
# Thế hệ 67: x = 0.8209, f(x) = 1.4142
# Thế hệ 68: x = 0.8209, f(x) = 1.4133
# Thế hệ 69: x = 0.7777, f(x) = 1.4133
# Thế hệ 70: x = 0.8060, f(x) = 1.4142
# Thế hệ 71: x = 0.8104, f(x) = 1.4139
# Thế hệ 72: x = 0.8104, f(x) = 1.4138
# Thế hệ 73: x = 0.8691, f(x) = 1.4138
# Thế hệ 74: x = 0.8750, f(x) = 1.4093
# Thế hệ 75: x = 0.7866, f(x) = 1.4085
# Thế hệ 76: x = 0.7906, f(x) = 1.4142
# Thế hệ 77: x = 0.8201, f(x) = 1.4142
# Thế hệ 78: x = 0.8377, f(x) = 1.4134
# Thế hệ 79: x = 0.7309, f(x) = 1.4123
# Thế hệ 80: x = 0.7968, f(x) = 1.4121
# Thế hệ 81: x = 0.8176, f(x) = 1.4141
# Thế hệ 82: x = 0.7843, f(x) = 1.4135
# Thế hệ 83: x = 0.8554, f(x) = 1.4142
# Thế hệ 84: x = 0.7937, f(x) = 1.4107
# Thế hệ 85: x = 0.7924, f(x) = 1.4142
# Thế hệ 86: x = 0.7853, f(x) = 1.4142
# Thế hệ 87: x = 0.7822, f(x) = 1.4142
# Thế hệ 88: x = 0.7814, f(x) = 1.4142
# Thế hệ 89: x = 0.7855, f(x) = 1.4142
# Thế hệ 90: x = 0.7848, f(x) = 1.4142
# Thế hệ 91: x = 0.7848, f(x) = 1.4142
# Thế hệ 92: x = 0.8233, f(x) = 1.4142
# Thế hệ 93: x = 0.8240, f(x) = 1.4132
# Thế hệ 94: x = 0.8314, f(x) = 1.4132
# Thế hệ 95: x = 0.8423, f(x) = 1.4127
# Thế hệ 96: x = 0.8516, f(x) = 1.4119
# Thế hệ 97: x = 0.8516, f(x) = 1.4111
# Thế hệ 98: x = 0.7600, f(x) = 1.4111
# Thế hệ 99: x = 0.7535, f(x) = 1.4138
# Thế hệ 100: x = 0.7266, f(x) = 1.4135
# Kết quả cuối cùng (Roulette): x = 0.7266, f(x) = 1.4118

# %% [markdown]
# # Bài tập 5
# # Trực quan hóa quần thể – Vẽ biểu đồ phân tán (scatter plot) thể hiện sự phân bố của quần thể qua các thế hệ
#
# ---
#
# ##  Mục tiêu
#
# - Trực quan hóa sự phân bố của quần thể cá thể trong quá trình tiến hóa của thuật toán di truyền.
# - Dùng biểu đồ phân tán (scatter plot) để thể hiện vị trí các cá thể trên không gian biến số qua từng thế hệ.
# - Giúp quan sát rõ tiến trình hội tụ, đa dạng di truyền, và sự thay đổi quần thể theo thời gian.
#
# ---
#
# ## Ý tưởng thực hiện
#
# - Với bài toán tối ưu hàm $k(x, y, z) = x^2 + y^2 + z^2$, không gian tìm kiếm là 3 chiều.
# - Mỗi cá thể là một điểm trong không gian $(x, y, z)$.
# - Ở mỗi thế hệ, lấy vị trí giải mã của toàn bộ cá thể, vẽ scatter plot.
# - Nếu không thể trực quan 3D trực tiếp, có thể vẽ scatter 2D từng cặp biến: $(x, y)$, $(y, z)$, $(x, z)$ qua các thế hệ.
#
# ---

# %%
import numpy as np
import math
import random
import matplotlib.pyplot as plt

# Hàm mục tiêu
def fitness_function(x):
    return math.sin(x) + math.cos(x)

# Khởi tạo quần thể
def initialize_population(pop_size, min_val, max_val):
    return [random.uniform(min_val, max_val) for _ in range(pop_size)]

# Lựa chọn (Tournament Selection)
def select_parents(population, fitness_values, tournament_size=3):
    selected = random.sample(range(len(population)), tournament_size)
    best_idx = max(selected, key=lambda i: fitness_values[i])
    return population[best_idx]

# Lai ghép
def crossover(parent1, parent2, crossover_rate=0.8):
    if random.random() < crossover_rate:
        return (parent1 + parent2) / 2
    return parent1

# Đột biến
def mutate(individual, mutation_rate=0.1, min_val=0, max_val=2*math.pi):
    if random.random() < mutation_rate:
        return random.uniform(min_val, max_val)
    return individual

# Thuật toán di truyền
def genetic_algorithm_example1(pop_size=50, generations=100, min_val=0, max_val=2*math.pi):
    population = initialize_population(pop_size, min_val, max_val)
    best_fitness_history = []
    population_history = []  # lưu quần thể qua các thế hệ
    
    for generation in range(generations):
        fitness_values = [fitness_function(x) for x in population]
        best_fitness = max(fitness_values)
        best_fitness_history.append(best_fitness)
        
        # Lưu quần thể của thế hệ hiện tại vào history
        for x in population:
            population_history.append((x, generation))
        
        new_population = []
        for _ in range(pop_size):
            parent1 = select_parents(population, fitness_values)
            parent2 = select_parents(population, fitness_values)
            child = crossover(parent1, parent2)
            child = mutate(child)
            new_population.append(child)
        
        population = new_population
        best_individual = population[np.argmax([fitness_function(x) for x in population])]
        print(f'Thế hệ {generation + 1}: x = {best_individual:.4f}, f(x) = {best_fitness:.4f}')
    
    # Trực quan hóa giá trị fitness tốt nhất
    plt.plot(range(generations), best_fitness_history)
    plt.xlabel('Thế hệ')
    plt.ylabel('Giá trị f(x) tốt nhất')
    plt.title('Sự thay đổi của f(x) qua các thế hệ')
    plt.show()

    # Vẽ scatter plot phân bố quần thể
    xs, gens = zip(*population_history)
    plt.scatter(xs, gens, alpha=0.5, s=10, c=gens, cmap='viridis')
    plt.xlabel('Giá trị cá thể x')
    plt.ylabel('Thế hệ')
    plt.title('Phân bố quần thể qua các thế hệ')
    plt.colorbar(label='Thế hệ')
    plt.show()
    
    best_fitness = max([fitness_function(x) for x in population])
    best_individual = population[np.argmax([fitness_function(x) for x in population])]
    
    return best_individual, best_fitness

# Chạy thuật toán
best_x, best_f = genetic_algorithm_example1()
print(f'\nKết quả cuối cùng: x = {best_x:.4f}, f(x) = {best_f:.4f}')
# Out:
# Thế hệ 1: x = 0.6666, f(x) = 1.4105
# Thế hệ 2: x = 0.7889, f(x) = 1.4043
# Thế hệ 3: x = 0.7856, f(x) = 1.4142
# Thế hệ 4: x = 0.7856, f(x) = 1.4142
# Thế hệ 5: x = 0.7858, f(x) = 1.4142
# Thế hệ 6: x = 0.7855, f(x) = 1.4142
# Thế hệ 7: x = 0.7853, f(x) = 1.4142
# Thế hệ 8: x = 0.7854, f(x) = 1.4142
# Thế hệ 9: x = 0.7854, f(x) = 1.4142
# Thế hệ 10: x = 0.7854, f(x) = 1.4142
# Thế hệ 11: x = 0.7854, f(x) = 1.4142
# Thế hệ 12: x = 0.7854, f(x) = 1.4142
# Thế hệ 13: x = 0.7854, f(x) = 1.4142
# Thế hệ 14: x = 0.7854, f(x) = 1.4142
# Thế hệ 15: x = 0.7854, f(x) = 1.4142
# Thế hệ 16: x = 0.7854, f(x) = 1.4142
# Thế hệ 17: x = 0.7854, f(x) = 1.4142
# Thế hệ 18: x = 0.7854, f(x) = 1.4142
# Thế hệ 19: x = 0.7854, f(x) = 1.4142
# Thế hệ 20: x = 0.7854, f(x) = 1.4142
# Thế hệ 21: x = 0.7854, f(x) = 1.4142
# Thế hệ 22: x = 0.7854, f(x) = 1.4142
# Thế hệ 23: x = 0.7854, f(x) = 1.4142
# Thế hệ 24: x = 0.7854, f(x) = 1.4142
# Thế hệ 25: x = 0.7854, f(x) = 1.4142
# Thế hệ 26: x = 0.7854, f(x) = 1.4142
# Thế hệ 27: x = 0.7854, f(x) = 1.4142
# Thế hệ 28: x = 0.7854, f(x) = 1.4142
# Thế hệ 29: x = 0.7854, f(x) = 1.4142
# Thế hệ 30: x = 0.7854, f(x) = 1.4142
# Thế hệ 31: x = 0.7854, f(x) = 1.4142
# Thế hệ 32: x = 0.7854, f(x) = 1.4142
# Thế hệ 33: x = 0.7854, f(x) = 1.4142
# Thế hệ 34: x = 0.7854, f(x) = 1.4142
# Thế hệ 35: x = 0.7854, f(x) = 1.4142
# Thế hệ 36: x = 0.7854, f(x) = 1.4142
# Thế hệ 37: x = 0.7854, f(x) = 1.4142
# Thế hệ 38: x = 0.7854, f(x) = 1.4142
# Thế hệ 39: x = 0.7854, f(x) = 1.4142
# Thế hệ 40: x = 0.7854, f(x) = 1.4142
# Thế hệ 41: x = 0.7854, f(x) = 1.4142
# Thế hệ 42: x = 0.7854, f(x) = 1.4142
# Thế hệ 43: x = 0.7854, f(x) = 1.4142
# Thế hệ 44: x = 0.7854, f(x) = 1.4142
# Thế hệ 45: x = 0.7854, f(x) = 1.4142
# Thế hệ 46: x = 0.7854, f(x) = 1.4142
# Thế hệ 47: x = 0.7854, f(x) = 1.4142
# Thế hệ 48: x = 0.7854, f(x) = 1.4142
# Thế hệ 49: x = 0.7854, f(x) = 1.4142
# Thế hệ 50: x = 0.7854, f(x) = 1.4142
# Thế hệ 51: x = 0.7854, f(x) = 1.4142
# Thế hệ 52: x = 0.7854, f(x) = 1.4142
# Thế hệ 53: x = 0.7854, f(x) = 1.4142
# Thế hệ 54: x = 0.7854, f(x) = 1.4142
# Thế hệ 55: x = 0.7854, f(x) = 1.4142
# Thế hệ 56: x = 0.7854, f(x) = 1.4142
# Thế hệ 57: x = 0.7854, f(x) = 1.4142
# Thế hệ 58: x = 0.7854, f(x) = 1.4142
# Thế hệ 59: x = 0.7854, f(x) = 1.4142
# Thế hệ 60: x = 0.7854, f(x) = 1.4142
# Thế hệ 61: x = 0.7854, f(x) = 1.4142
# Thế hệ 62: x = 0.7854, f(x) = 1.4142
# Thế hệ 63: x = 0.7854, f(x) = 1.4142
# Thế hệ 64: x = 0.7854, f(x) = 1.4142
# Thế hệ 65: x = 0.7854, f(x) = 1.4142
# Thế hệ 66: x = 0.7854, f(x) = 1.4142
# Thế hệ 67: x = 0.7854, f(x) = 1.4142
# Thế hệ 68: x = 0.7854, f(x) = 1.4142
# Thế hệ 69: x = 0.7854, f(x) = 1.4142
# Thế hệ 70: x = 0.7854, f(x) = 1.4142
# Thế hệ 71: x = 0.7854, f(x) = 1.4142
# Thế hệ 72: x = 0.7854, f(x) = 1.4142
# Thế hệ 73: x = 0.7854, f(x) = 1.4142
# Thế hệ 74: x = 0.7854, f(x) = 1.4142
# Thế hệ 75: x = 0.7854, f(x) = 1.4142
# Thế hệ 76: x = 0.7854, f(x) = 1.4142
# Thế hệ 77: x = 0.7854, f(x) = 1.4142
# Thế hệ 78: x = 0.7854, f(x) = 1.4142
# Thế hệ 79: x = 0.7854, f(x) = 1.4142
# Thế hệ 80: x = 0.7854, f(x) = 1.4142
# Thế hệ 81: x = 0.7854, f(x) = 1.4142
# Thế hệ 82: x = 0.7854, f(x) = 1.4142
# Thế hệ 83: x = 0.7854, f(x) = 1.4142
# Thế hệ 84: x = 0.7854, f(x) = 1.4142
# Thế hệ 85: x = 0.7854, f(x) = 1.4142
# Thế hệ 86: x = 0.7854, f(x) = 1.4142
# Thế hệ 87: x = 0.7854, f(x) = 1.4142
# Thế hệ 88: x = 0.7854, f(x) = 1.4142
# Thế hệ 89: x = 0.7854, f(x) = 1.4142
# Thế hệ 90: x = 0.7854, f(x) = 1.4142
# Thế hệ 91: x = 0.7854, f(x) = 1.4142
# Thế hệ 92: x = 0.7854, f(x) = 1.4142
# Thế hệ 93: x = 0.7854, f(x) = 1.4142
# Thế hệ 94: x = 0.7854, f(x) = 1.4142
# Thế hệ 95: x = 0.7854, f(x) = 1.4142
# Thế hệ 96: x = 0.7854, f(x) = 1.4142
# Thế hệ 97: x = 0.7854, f(x) = 1.4142
# Thế hệ 98: x = 0.7854, f(x) = 1.4142
# Thế hệ 99: x = 0.7854, f(x) = 1.4142
# Thế hệ 100: x = 0.7854, f(x) = 1.4142
# Kết quả cuối cùng: x = 0.7854, f(x) = 1.4142

# %% [markdown]
# ## Hướng dẫn thực hiện
# 1. Chạy từng đoạn code trong Jupyter Notebook.
# 2. Quan sát kết quả và biểu đồ.
# 3. Thử nghiệm với các tham số và bài tập mở rộng.
# 4. Ghi chú lại các kết quả và phân tích sự khác biệt.

# %% [markdown]
# # Nộp Github
